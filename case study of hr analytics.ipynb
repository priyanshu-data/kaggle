# %% [markdown]
# # Importing the libraries required for the execution.

# %%
import numpy as np 
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# # First we will see the general data and try to figure out something.

# %%
General_data =pd.read_csv("C:/Users/PRIYA/Desktop/general_data.csv")

# %%
General_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
General_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %% [markdown]
# # Let's check the count of the dataset.

# %%
General_data.shape
# Out:
# (4410, 24)

# %%
General_data.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %% [markdown]
# # let's see the count for the null value.

# %%
General_data.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
General_data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# here i see,NumCompaniesWorked have 19 null values,so we need to apply feature engineering to fill the empty spaces.

# %% [markdown]
# # We can also use seaborn library to see the missing values.

# %%
sns.heatmap(General_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# Now filling the missing value with something,by seeing the data i am assuming that he may be fresher ,so i am putting it to 'zero'.

# %% [markdown]
# # We can even use boxplot for filling the empty spaces,by mean fitting.

# %%
#filling the missing values.
General_data.fillna(0,inplace=True)

# %%
General_data.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# # Now there are no null values.

# %% [markdown]
# # Let's also check if we can drop some feature(unwanted feature).

# %% [markdown]
# I don't require employee ID(is not important for the analysis),employee count (as all are '1' ) and standard hours(as all are '8'),we can drop these features.

# %%
General_data.drop(['EmployeeCount','EmployeeID','StandardHours'],axis=1,inplace=True)

# %% [markdown]
# # Let's do some visualization for correlation

# %%
General_data.corr()
# Out:
#                               Age  DistanceFromHome  Education  JobLevel  \
# Age                      1.000000          0.006963  -0.035706 -0.002884
# DistanceFromHome         0.006963          1.000000  -0.008638 -0.037329
# Education               -0.035706         -0.008638   1.000000  0.045746
# JobLevel                -0.002884         -0.037329   0.045746  1.000000
# MonthlyIncome           -0.044314         -0.021607   0.006410  0.047316
# NumCompaniesWorked       0.299297         -0.012617  -0.016096 -0.010877
# PercentSalaryHike       -0.033137          0.038125  -0.040531  0.010973
# StockOptionLevel        -0.031753          0.011169   0.001261  0.000993
# TotalWorkingYears        0.678436          0.008925  -0.011581 -0.035498
# TrainingTimesLastYear   -0.027308         -0.009001   0.010472 -0.032500
# YearsAtCompany           0.311309          0.031684   0.006080 -0.064219
# YearsSinceLastPromotion  0.216513          0.002290   0.022490 -0.060811
# ...

# %%
General_data1=General_data.corr()
plt.figure(figsize=(16,10))
sns.heatmap(General_data1,annot=True)

# %% [markdown]
# # From the heatmap i can say every feature is independent ,we can proceed to next stage.

# %%
#As our target variable is ATTRITION,so we will look at the count of 'yes' and 'no'.

# %%
sns.countplot(x='Attrition',data=General_data)

# %%
print(len(General_data[General_data['Attrition']=='Yes']))
print(len(General_data[General_data['Attrition']=='No']))
# Out:
# 711
# 3699

# %% [markdown]
# we see,711 counts leaves the company

# %% [markdown]
# # Now we will see how many where women and how many where men.

# %%
sns.countplot(x='Attrition',data=General_data,hue="Gender")

# %% [markdown]
# I see,amongst the leaving male ratio is more.
# Now,i will try to see amongst the leaving what was their jobtype.

# %%
sns.countplot(x = "Attrition",data=General_data,hue="JobLevel")

# %% [markdown]
# I see job level of 1 and 2 are more.
#
# Next let's see the Age feature .

# %% [markdown]
# # Firstly i see the minimum an the maximum value of the 'AGE' feature.

# %%
def Age(feature):
    feature.loc[feature['Age'] <= 30,'Age'] = 1
    feature.loc[(feature['Age'] > 30) & (feature['Age'] <= 40), 'Age'] = 2
    feature.loc[(feature['Age'] > 40) & (feature['Age'] <= 50), 'Age'] = 3
    feature.loc[(feature['Age'] > 50) & (feature['Age'] <= 60), 'Age'] = 4
    return feature

Age(General_data);

# %%
General_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0    4        No      Travel_Rarely                   Sales                 6
# 1    2       Yes  Travel_Frequently  Research & Development                10
# 2    2        No  Travel_Frequently  Research & Development                17
# 3    2        No         Non-Travel  Research & Development                 2
# 4    2        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  Gender  JobLevel                    JobRole  ...  \
# 0          2  Life Sciences  Female         1  Healthcare Representative  ...
# 1          1  Life Sciences  Female         1         Research Scientist  ...
# 2          4          Other    Male         4            Sales Executive  ...
# 3          5  Life Sciences    Male         3            Human Resources  ...
# 4          1        Medical    Male         1            Sales Executive  ...
#
# ...

# %%
sns.countplot(x='Attrition',hue='Age',data=General_data)

# %% [markdown]
# We see that age group of 1 and 2 are more.

# %% [markdown]
# And I also found out all the features are categorical ,so we need to convert it into numbers,some needs to be dropped

# %%
print(General_data['BusinessTravel'].unique())
#so for the other features also.
# Out:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']

# %% [markdown]
# # So,we have bussiness travel,education field,gender,department,jobrole,marital status,over 18,that needed to be converted

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelEncoder_X = LabelEncoder()
General_data['BusinessTravel'] = labelEncoder_X.fit_transform(General_data['BusinessTravel'])
General_data['Department'] = labelEncoder_X.fit_transform(General_data['Department'])
General_data['EducationField'] = labelEncoder_X.fit_transform(General_data['EducationField'])
General_data['Gender'] = labelEncoder_X.fit_transform(General_data['Gender'])
General_data['JobRole'] = labelEncoder_X.fit_transform(General_data['JobRole'])
General_data['MaritalStatus'] = labelEncoder_X.fit_transform(General_data['MaritalStatus'])
General_data['Over18'] = labelEncoder_X.fit_transform(General_data['Over18'])
General_data['Attrition']=labelEncoder_X.fit_transform(General_data['Attrition'])

# %%
General_data.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0    4          0               2           2                 6          2
# 1    2          1               1           1                10          1
# 2    2          0               1           1                17          4
# 3    2          0               0           1                 2          5
# 4    2          0               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  ...  MonthlyIncome  \
# 0               1       0         1        0  ...         131160
# 1               1       0         1        6  ...          41890
# 2               4       1         4        7  ...         193280
# 3               1       1         3        1  ...          83210
# 4               3       1         1        7  ...          23420
#
#    NumCompaniesWorked  Over18  PercentSalaryHike  StockOptionLevel  \
# ...

# %%
df2=General_data.corr()
plt.figure(figsize=(16,10))
sns.heatmap(df2,annot=True)

# %% [markdown]
# We made a mistake ,we need to drop over 18 feature,or we can make it as 1.

# %%
df3=General_data[['Age','Attrition','BusinessTravel','DistanceFromHome','Education', 'EducationField','Gender', 'JobLevel', 'JobRole',
       'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
df_1=df3.corr()
plt.figure(figsize=(18,10))
sns.heatmap(df_1,annot=True)

# %% [markdown]
# # Now,we will be splitting the data.

# %%
General_data.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0    4          0               2           2                 6          2
# 1    2          1               1           1                10          1
# 2    2          0               1           1                17          4
# 3    2          0               0           1                 2          5
# 4    2          0               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  ...  MonthlyIncome  \
# 0               1       0         1        0  ...         131160
# 1               1       0         1        6  ...          41890
# 2               4       1         4        7  ...         193280
# 3               1       1         3        1  ...          83210
# 4               3       1         1        7  ...          23420
#
#    NumCompaniesWorked  Over18  PercentSalaryHike  StockOptionLevel  \
# ...

# %%
#Spliting the data into training and test data
y = General_data['Attrition']
x = General_data.drop('Attrition', axis = 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
Scaler_X = StandardScaler()
X_train = Scaler_X.fit_transform(X_train)
X_test = Scaler_X.transform(X_test)

# %%
#import some comman libs:
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.8378684807256236
# [[732   9]
#  [134   7]]

# %% [markdown]
# # from this i can say my model predict 83% right values.
